# %%
#                Artificial Intelligence Lab Week 2
# Lab Activity 1
# Accept two lists from user and display their join.

firstList = []
secondList = []
resultList = []
for i in range(0,5):
  firstList.append(int(input("Enter First List Element: ")))

for i in range(0,5):
  secondList.append(int(input("Enter Second List Element: ")))

resultList = firstList + secondList
print(resultList)
# Out:
# Enter First List Element: 1
# Enter First List Element: 1
# Enter First List Element: 1
# Enter First List Element: 1
# Enter First List Element: 1
# Enter Second List Element: 4
# Enter Second List Element: 4
# Enter Second List Element: 4
# Enter Second List Element: 4
# Enter Second List Element: 4
# [1, 1, 1, 1, 1, 4, 4, 4, 4, 4]

# %%
# Lab Activity 2
# A palindrome is a string which is same read forward or backwards.
# Return true if string is palindrome else return false

word = input("Enter a String: ")
if word == word[::-1]:
  print(f"{word} is Palindrome")
else:
  print(f"{word} is not Palindrome")
# Out:
# Enter a String: deed
# deed is Palindrome

# %%
# Lab Acivity 3
# Fond the product of two 2D matrices and store in new 2D matrix

firstMatrix = [[1,3] , [2,5]]
secondMatrix = [[3,2] , [9,9]]
resultMatrix = []

if len(firstMatrix) == len(secondMatrix):
  for i in range(0,len(firstMatrix)):
    resultMatrix.append([])
    for j in range(0,len(firstMatrix)):
      resultMatrix[i].append(0)

  for row in range(0,len(firstMatrix)):
    for col in range(0,len(firstMatrix)):
      for k in range(0,len(firstMatrix)):
        resultMatrix[row][col] += firstMatrix[row][k] * secondMatrix[k][col]
  print(f"Product of two 2D matrices is: {resultMatrix}")
else:
  print("Matrices is incompatible for product")
# Out:
# Product of two 2D matrices is: [[30, 29], [51, 49]]

# %%
# Lab Activity 4
# Write a python function that takes a list of N tuples as input and returns the perimeter of the
# polygon. Remember that your code should work for any value of N.

def perimeterofN(listNumbers):
    lengthOfList = len(listNumbers)
    perimeter = 0
    
    for i in range(0, lengthOfList-1):
        distance = (((listNumbers[i][0] - listNumbers[i+1][0]) **2)
                   + ((listNumbers[i][1] - listNumbers[i+1][1]) **2)) ** 0.5
        perimeter += distance
    perimeter += (((listNumbers[0][0] - listNumbers[lengthOfList-1][0]) ** 2)+
                 ((listNumbers[0][1] - listNumbers[lengthOfList-1][1]) ** 2)) ** 0.5
    return perimeter
inputList = [(1,9) , (2,7), (1,1)]
print(perimeterofN(inputList))
# Out:
# 16.31883050779801

# %%
# Lab Activity 5
# Imagine two sets A and B containing numbers. Without using built-in set functionalities, 
# write your own function that receives two such sets and returns another set 
# C which is a symmetric difference of the two input sets. 

def checkSymmetric(set1 , set2):
    result=set()
    for i in set1:
        if i not in set2:
            result.add(i)
    for j in set2:
        if j not in set1:
            result.add(j)
    return result

set1 = {1,2,9,0,8,4,6}
set2 = {3,9,8,7}
print(checkSymmetric(set1, set2))
# Out:
# {0, 1, 2, 3, 4, 6, 7}

# %%
# Lab Activity 6
# Create a Python program that contains a dictionary of names and phone numbers. 
# Use a tuple of separate first and last name values for the key field. 
# Initialize the dictionary with at least three names and numbers.

dictionary = {("Usama" , "Mansoor"): "03333333333", ("Ali","Minhas"): "03332921098" , ("Muhammad","Awais"): "03339087621"}
fname = input("Enter First Name: ")
lname = input("Enter Last Name: ")

search = (fname , lname)
if search in dictionary:
    print(search , " : " , dictionary[search])
else:
    print("Not Found")
# Out:
# Enter First Name: Usama
# Enter Last Name: Mansoor
# ('Usama', 'Mansoor')  :  03333333333

# %%
# Lab Task 1
# Create two lists based on the user values. Merge both the lists and display in sorted order.

FirstList = []
SecondList = []

lengthfirstList = int(input("Enter the length of First List: "))
for i in range(0,lengthfirstList):
  FirstList.append(int(input("Enter First List Element: ")))

lengthSecondList = int(input("Enter the length of Second List: "))
for i in range(0,lengthSecondList):
  SecondList.append(int(input("Enter Second List Element: ")))

resultList = FirstList + SecondList
resultLength = len(resultList)
for i in range(resultLength):
  for j in range(i+1, resultLength):
    if (resultList[i] > resultList[j]):
      temp = resultList[i]
      resultList[i] = resultList[j]
      resultList[j] = temp

print(sorted(resultList))
# Out:
# Enter the length of First List: 3
# Enter First List Element: 9
# Enter First List Element: 1
# Enter First List Element: 6
# Enter the length of Second List: 2
# Enter Second List Element: 3
# Enter Second List Element: 4
# [1, 3, 4, 6, 9]

# %%
# Lab Task 2
# Find the Largest and Smallest Number in List

myList = []
length = int(input("Enter the length of the list: "))

for i in range(0,length):
  myList.append(int(input("Enter Element: ")))

for i in range(0,length):
  for j in range(i+1 , length):
    if myList[i] > myList[j]:
      temp = myList[i]
      myList[i] = myList[j]
      myList[j] = temp
print(f"Largest Number is: {myList[-1]}")
print(f"Smallest Number is: {myList[0]}")
# Out:
# Enter the length of the list: 4
# Enter Element: 100
# Enter Element: 1
# Enter Element: 90
# Enter Element: 2
# Largest Number is: 100
# Smallest Number is: 1

# %%
# Lab task 3

import math
import numpy as np

posPi = math.pi
negPi = -(math.pi)
myList = []
cosValueList = []
sinValueList = []
h = 0.001
resultList = []
for i in np.arange(negPi , posPi , 0.001):
  myList.append(i)

for i in np.arange(negPi , posPi , 0.001):
  cosValueList.append(math.cos(i))

for i in np.arange(negPi , posPi , 0.001):
  temp = (math.sin(i + h) - math.sin(i)) / h
  sinValueList.append(temp)

# for i in np.arange(negPi , posPi , 0.001):
#   if sinValueList[i] == cosValueList[i]:
#     resultList.append(i)
#   else:
#     continue
print("")
print("List of values from -pi to +pi: " , myList)
print("")
print("Cos Value List" , cosValueList)
print("")
print("Sin Value List: " , sinValueList)
# Out:
# List of values from -pi to +pi:  [-3.141592653589793, -3.1405926535897932, -3.1395926535897933, -3.1385926535897934, -3.1375926535897936, -3.1365926535897937, -3.1355926535897938, -3.134592653589794, -3.133592653589794, -3.132592653589794, -3.131592653589794, -3.1305926535897943, -3.1295926535897944, -3.1285926535897945, -3.1275926535897947, -3.1265926535897948, -3.125592653589795, -3.124592653589795, -3.123592653589795, -3.122592653589795, -3.1215926535897953, -3.1205926535897954, -3.1195926535897955, -3.1185926535897
076277489126, -0.9958167532996692, -0.9957248830337467, -0.9956320170430161, -0.9955381554203613, -0.995443298259624, -0.9953474456556866, -0.9952505977043891, -0.9951527545025568, -0.9950539161480559, -0.994954082739738, -0.994853254377398, -0.9947514311619138, -0.9946486131950649, -0.9945448005796859, -0.9944399934195824, -0.9943341918195875, -0.9942273958854636, -0.994119605724042, -0.9940108214430976, -0.9939010431514045, -0.9937902709587498, -0.99367850497592, -0.993565745314659, -0.9934519920877238, -0.9933372454089123, -0.9932215053929105, -0.993104772155487, -0.9929870458133816, -0.9928683264843197, -0.9927486142870118, -0.9926279093411539, -0.9925062117674965, -0.9923835216876786, -0.9922598392244492, -0.9921351645014453, -0.9920094976433869, -0.9918828387758816, -0.9917551880256337, -0.9916265455202911, -0.9914969113884731, -0.9913662857597982, -0.9912346687649676, -0.9911020605355425, -0.9909684612041392, -0.9908338709043174, -0.9906982897707473, -0.990561717938987, -0.9904241555455384, -0.9902856027280416, -0.9901460596250244, -0.9900055263760421, -0.9898640031215933, -0.9897214900032592, -0.9895779871634813, -0.9894334947458117, -0.9892880128947179, -0.9891415417557226, -0.9889940814752363, -0.9888456322007799, -0.9886961940807626, -0.9885457672646203, -0.9883943519027882, -0.9882419481467286, -0.988088556148764, -0.987934176062355, -0.9877788080418226, -0.9876224522425703, -0.9874651088209452, -0.9873067779343214, -0.987147459740989, -0.9869871544002651, -0.9868258620724657, -0.9866635829189063, -0.986500317101846, -0.9863360647845432, -0.9861708261312552, -0.9860046013072388, -0.9858373904786666, -0.9856691938128215, -0.9855000114778467, -0.9853298436429403, -0.9851586904782994, -0.9849865521550372, -0.9848134288452937, -0.9846393207222082, -0.9844642279598637, -0.9842881507334256, -0.9841110892188643, -0.9839330435933435, -0.9837540140348044, -0.9835740007223814, -0.9833930038360417, -0.9832110235567515, -0.9830280600665042, -0.9828441135483479, -0.9826591841860799, -0.9824732721647744, -0.9822863776702273, -0.9820985008894279, -0.9819096420 ...

# %%
# Lab task 4
# For this exercise, you will keep track of when our friend’s birthdays are, 
# and be able to find that information based on their name.
# using dictionary

birthdayDictionary = {("Usama"): "16/11/2001" , ("Aamir"): "05/10/2000" , ("Alyaan"): "10/09/2001"}
print("Welcome to Birthday Dictionary: ")
birthday = input("Enter the name of a person you want to see his BirthDate: ")

search = birthday
if search in birthdayDictionary:
  print(search+"'s birthday is " , birthdayDictionary[search])
else:
  print("Not Found Sorry")
# Out:
# Welcome to Birthday Dictionary:
# Enter the name of a person you want to see his BirthDate: Usama
# Usama's birthday is  16/11/2001

# %%
# Lab Task 5
# Create a dictionary by extracting the keys from a given dictionary
# Write a Python program to create a new dictionary by extracting the mentioned keys from the below dictionary.

sampleDict = {("name"): "Usama" , ("age"): "20" , ("salary"): "500000" , ("city"): "Kamra"}

keys = {key: sampleDict[key] for key in sampleDict.keys() & {'name' , 'salary'}}

print(keys)
# Out:
# {'name': 'Usama', 'salary': '500000'}
